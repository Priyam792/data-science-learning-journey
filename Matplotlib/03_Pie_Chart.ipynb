# %% [markdown]
# # Matplotlib Pie Charts
# - Pie charts are used to show part-to-whole relationships. They're visually appealing but best used with fewer categories, as too many slices can get cluttered and hard to interpret.

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use("ggplot")

# %%
labels = ["Sachin", "Sehwag", "Kohli", "Yuvraj"]
runs = [18000, 8000, 12000, 9500]
plt.title("Career Runs of Indian Batsmen")
plt.pie(runs, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9eaab06e40>,
#   <matplotlib.patches.Wedge at 0x7f9eaab307d0>,
#   <matplotlib.patches.Wedge at 0x7f9eaab30910>,
#   <matplotlib.patches.Wedge at 0x7f9eaab30b90>],
#  [Text(0.408316888704146, 1.0214094763604684, 'Sachin'),
#   Text(-1.0706592615758088, 0.25236629252327625, 'Sehwag'),
#   Text(-0.5074755072212109, -0.9759449828604966, 'Kohli'),
#   Text(0.8899186414035474, -0.6465638496563697, 'Yuvraj')])

# %% [markdown]
# ## Custom Colors
# - You can use color names or hex codes.

# %%
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
plt.pie(runs, labels=labels, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9eaaba20d0>,
#   <matplotlib.patches.Wedge at 0x7f9eaaba2350>,
#   <matplotlib.patches.Wedge at 0x7f9eaaba25d0>,
#   <matplotlib.patches.Wedge at 0x7f9eaaba2850>],
#  [Text(0.408316888704146, 1.0214094763604684, 'Sachin'),
#   Text(-1.0706592615758088, 0.25236629252327625, 'Sehwag'),
#   Text(-0.5074755072212109, -0.9759449828604966, 'Kohli'),
#   Text(0.8899186414035474, -0.6465638496563697, 'Yuvraj')])

# %% [markdown]
# ## Add Edges and Style Slices with wedgeprops
# - You can customize the look of the slices using wedgeprops.

# %%
plt.pie(runs , labels=labels , colors = colors , 
        wedgeprops = {'edgecolor' : 'black' , 'linewidth' : 2 , 'linestyle' : ":"})
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9eaabea990>,
#   <matplotlib.patches.Wedge at 0x7f9eaabeac10>,
#   <matplotlib.patches.Wedge at 0x7f9eaabeae90>,
#   <matplotlib.patches.Wedge at 0x7f9eaabeb110>],
#  [Text(0.408316888704146, 1.0214094763604684, 'Sachin'),
#   Text(-1.0706592615758088, 0.25236629252327625, 'Sehwag'),
#   Text(-0.5074755072212109, -0.9759449828604966, 'Kohli'),
#   Text(0.8899186414035474, -0.6465638496563697, 'Yuvraj')])

# %% [markdown]
# ## Highlight a Slice Using explode
# - Use explode to pull out one or more slices.

# %%
explode = [0.1, 0, 0, 0]
# Only highlight Sachin's slice
plt.pie(runs, labels=labels, explode=explode, colors=colors)
plt.title("Exploded Pie Example")
# Out:
# Text(0.5, 1.0, 'Exploded Pie Example')

# %%
plt.pie(
runs,
labels=labels,
explode=explode,
colors=colors,
shadow=True # adds a 3D-like shadow
)
plt.show()

# %% [markdown]
# ## Start Angle
# - Use startangle to rotate the pie for better alignment.

# %%
plt.pie(runs , labels = labels , explode = explode , shadow = True , colors = colors , startangle = 120)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9eaa2c6710>,
#   <matplotlib.patches.Wedge at 0x7f9eaa2c6ad0>,
#   <matplotlib.patches.Wedge at 0x7f9eaa2c6e90>,
#   <matplotlib.patches.Wedge at 0x7f9eaa2c7250>],
#  [Text(-1.1876999475677512, -0.17137337759279064, 'Sachin'),
#   Text(0.3167743229484495, -1.0534011715963447, 'Sehwag'),
#   Text(1.0989308523976864, 0.048486922448167345, 'Kohli'),
#   Text(0.11498081286296255, 1.0939741371135665, 'Yuvraj')])

# %% [markdown]
# # Show Percentages with autopct

# %%
plt.pie(
runs,
labels=labels,
autopct='%1.1f%%', # <------------------------
startangle=140
)
plt.title("Career Run Share")
# Out:
# Text(0.5, 1.0, 'Career Run Share')

# %% [markdown]
# # Assignment:
# - Create a pie chart showing the market share of mobile OS (Android, iOS, others). Then recreate the same using a horizontal bar chart and observe which is easier to understand.

# %%
os = ["Android", "iOS", "Others"]
market_share = [72, 26, 2]

# %%
plt.pie( market_share, labels = os , autopct= '%1.1f%%' ,shadow = True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9eaa166c10>,
#   <matplotlib.patches.Wedge at 0x7f9eaa167110>,
#   <matplotlib.patches.Wedge at 0x7f9eaa167610>],
#  [Text(-0.7011665633180723, 0.847564422616195, 'Android'),
#   Text(0.6465640158668551, -0.8899185206445168, 'iOS'),
#   Text(1.0978294115800824, -0.06906940762544606, 'Others')],
#  [Text(-0.38245448908258484, 0.4623078668815609, '72.0%'),
#   Text(0.3526712813819209, -0.4854101021697364, '26.0%'),
#   Text(0.598816042680045, -0.037674222341152384, '2.0%')])

# %%
plt.barh(os , market_share)
# Out:
# <BarContainer object of 3 artists>
