# %% [markdown]
# # Stack Plots in Matplotlib
# ---
# ## A Stack Plot is a type of area chart that helps visualize multiple quantities over time, stacked on top of each other. It's especially useful to see how individual parts contribute to a whole over time.
#
#
# ***Use Cases:***
#
# - Time spent on different activities over days
# - Distribution of tasks by team members over a project timeline
# - Website traffic sources over a week

# %%
import matplotlib.pyplot as plt

days = [1, 2, 3, 4, 5, 6, 7] # Days of the week
studying = [3, 4, 3, 5, 4, 3, 4]
playing = [2, 2, 1, 1, 2, 3, 2]
watching_tv = [2, 1, 2, 2, 1, 1, 1]
sleeping = [5, 5, 6, 5, 6, 5, 5]

labels = ['Study', 'Play','TV','Sleeping']
colors = ['red','yellow', 'green', 'orange']

plt.stackplot(days , studying , playing , watching_tv , sleeping, labels = labels , colors = colors , alpha = 0.5)
plt.tight_layout()
plt.title('Weekly time schedule')
plt.xlabel("Days")
plt.ylabel("Activities")
plt.legend()

# %% [markdown]
# # ***Quick quiz***
# - ## Try making a stackplot with your own weekly schedule!

# %%
import pandas as pd

# %%
df = pd.read_csv("weekly-schedule.csv")
df.columns[1:]
# Out:
# Index(['Study', 'Classes', 'Exercise', 'Sleep', 'Leisure', 'Coding', 'Other'], dtype='object')

# %%
plt.stackplot(df['Day'], df['Study'], df['Classes'],df['Exercise'],df['Sleep'],df['Leisure'],df['Coding'],df['Other'], labels = df.columns[1:], alpha = 0.7)
plt.legend()
plt.xlabel('Days')
plt.ylabel("Hours")
plt.title("My daily Schedule")
plt.grid(True)
